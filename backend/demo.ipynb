# %%
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 21
#      17 load_dotenv()
#      19 app = FastAPI()
# ---> 21 model = ChatOpenAI(
#      22     model = 'c1/openai/gpt-5/v-20250930',
#      23     base_url = 'https://api.thesys.dev/v1/embed/'
#      24 )
#      26 checkpointer = InMemorySaver()
#      29 @tool('get_stock_price', description='A function that returns the current stock price based on a ticker symbol.')
#      30 def get_stock_price(ticker: str):
#
# File c:\Users\Nirvan\AppData\Local\Programs\Python\Python39\lib\site-packages\langchain_core\load\serializable.py:115, in Serializable.__init__(self, *args, **kwargs)
#     113 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     114     """"""  # noqa: D419  # Intentional blank docstring
# --> 115     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# ...
